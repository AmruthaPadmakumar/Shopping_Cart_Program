# %%
store_items={"Biscuits":{"Srno":1,"stock":5,"cost":2.50},
             "Cereals":{"Srno":2,"stock":10,"cost":3.50},
             "Chicken":{"Srno":3,"stock":20,"cost":13.30},
             "Oats":{"Srno":4,"stock":20,"cost":3.90},
             "Rice":{"Srno":5,"stock":30,"cost":4.50}}
print("WELCOME !!")
print("             ESSENTIAL ITEMS AVIALABLE")
print("%10s %10s %10s %10s"%("S.no","Item","Quantity","Cost/Item"))
for name, data in store_items.items():
    print("%10d %10s %10d %10d"%(data["Srno"],name,data["stock"],data["cost"]))
    
print("Fill your delivery details")
person_name = input("Enter your name: ")
address = input("Enter your address: ")
distance = float(input("Enter distance of delivery address 0-5/5-10/10-15/above15 (in miles): "))
total_item_cost=0
while True:
    cart=[]
    
    bill_items=[]
    for name,data in store_items.items():
        while True:
            quantity=int(input("How many packets of "+name+" are required? "))
            if quantity <= data['stock']:
                cart.append(quantity)
                total_item_cost=total_item_cost+quantity*data["cost"]
                data["stock"]=data["stock"]-quantity
                bill_items.append({"Srno":data["Srno"],"Name":name,"Quantity":quantity,"Total Cost":quantity*data["cost"]})
                break
            elif data["stock"]==0:
                print("Sorry out of stock!!")
                break
            else:
                print("Sorry only",data["stock"]," are left")
                
            
            
           
    print("\n         ---------BILL-------\n")
    print("%10s %10s %10s %10s"%("S.no","Item","Quantity","Total Cost"))
    for item in bill_items:
        print("%10d %10s %10s %10.2f"%(item["Srno"],item["Name"],item["Quantity"],item["Total Cost"]))
        
    
    print("Total Item Cost=",total_item_cost)
    if distance<=5:
        delivery_charge=10
    elif distance>5 or distance>=10:
        delivery_charge=12
    elif distance>10 or distance>=15:
        delivery_charge=14
    else:
        delivery_charge=20
    print("Delivery Charge= ",delivery_charge)
    print("Total Bill Amount = Total Item Cost + Delivery Charge=$ ",total_item_cost + delivery_charge)
    print("\nName= ",person_name)
    print("Address= ",address)
    
    choice = input("\nDo you want to continue shopping? Enter y/n: ")
    if choice == 'n':
        break
# Out:
# WELCOME !!
#              ESSENTIAL ITEMS AVIALABLE
#       S.no       Item   Quantity  Cost/Item
#          1   Biscuits          5          2
#          2    Cereals         10          3
#          3    Chicken         20         13
#          4       Oats         20          3
#          5       Rice         30          4
# Fill your delivery details
# Enter your name: Amrutha Padmakumar
# Enter your address: Mumbai
# Enter distance of delivery address 0-5/5-10/10-15/above15 (in miles): 9
# How many packets of Biscuits are required? 5
# How many packets of Cereals are required? 12
# Sorry only 10  are left
# How many packets of Cereals are required? 8
# How many packets of Chicken are required? 5
# How many packets of Oats are required? 7
# How many packets of Rice are required? 8
#
#          ---------BILL-------
#
#       S.no       Item   Quantity Total Cost
#          1   Biscuits          5      12.50
#          2    Cereals          8      28.00
#          3    Chicken          5      66.50
#          4       Oats          7      27.30
#          5       Rice          8      36.00
# Total Item Cost= 170.3
# Delivery Charge=  12
# Total Bill Amount = Total Item Cost + Delivery Charge=$  182.3
#
# Name=  Amrutha Padmakumar
# Address=  Mumbai
#
# Do you want to continue shopping? Enter y/n: y
# How many packets of Biscuits are required? 5
# Sorry out of stock!!
# How many packets of Cereals are required? 6
# Sorry only 2  are left
# How many packets of Cereals are required? 2
# How many packets of Chicken are required? 7
# How many packets of Oats are required? 4
# How many packets of Rice are required? 7
#
#          ---------BILL-------
#
#       S.no       Item   Quantity Total Cost
#          2    Cereals          2       7.00
#          3    Chicken          7      93.10
#          4       Oats          4      15.60
#          5       Rice          7      31.50
# Total Item Cost= 317.50000000000006
# Delivery Charge=  12
# Total Bill Amount = Total Item Cost + Delivery Charge=$  329.50000000000006
#
# Name=  Amrutha Padmakumar
# Address=  Mumbai
#
# Do you want to continue shopping? Enter y/n: n
